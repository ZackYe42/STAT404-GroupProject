# %% [markdown]
# # STAT 404 Group Project

# %%
library(tidyverse)
library(infer)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 4.3.1"
# Warning message:
# "package 'purrr' was built under R version 4.3.1"
# Warning message:
# "package 'dplyr' was built under R version 4.3.1"
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Warning message:
# "package 'infer' was built under R version 4.3.1"

# %%
# Collected Data

df1 <- data.frame(Without_P = c(9,9,10,9,7,7), With_P = c(4,5,4,4,5,4), Surface_Area = rep(36.5, 6))
df2 <- data.frame(Without_P = c(13,11,10,11,10,12), With_P = c(12,8,10,10,9,7), Surface_Area = rep(38.5, 6))
df3 <- data.frame(Without_P = c(12,11,12,12,12,11), With_P = c(8,7,6,6,5,7), Surface_Area = rep(30.2, 6))
df <- rbind(df1,df2,df3)
df
# Out:
#    Without_P With_P Surface_Area
# 1   9         4     36.5
# 2   9         5     36.5
# 3  10         4     36.5
# 4   9         4     36.5
# 5   7         5     36.5
# 6   7         4     36.5
# 7  13        12     38.5
# 8  11         8     38.5
# 9  10        10     38.5
# 10 11        10     38.5
# 11 10         9     38.5
# 12 12         7     38.5
# 13 12         8     30.2
# 14 11         7     30.2
# 15 12         6     30.2
# 16 12         6     30.2
# 17 12         5     30.2
# 18 11         7     30.2

# %%
boxplot(df1[,1:2])
boxplot(df2[,1:2])
boxplot(df3[,1:2])
ggplot(df1) + 
    geom_boxplot(aes(Without_P))
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
